# %% [markdown]
# # **CSE655 Midterm Notes**
#
# 1. **Perceptron**
# 2. **Loss Function**
# 3. **Activation Functions (Sigmoid, ReLU, Tanh)**
# 4. **Feed Forward Networks**
# 5. **Gradient Descent**
# 6. **Stochastic Gradient Descent (SGD)**
# 7. **Mini-batch Gradient Descent**
# 8. **Adam Optimizer**
# 9. **Back Propagation**
# 10. **Vanishing and Exploding Gradients**
# 11. **Bias-Variance Tradeoff**
# 12. **Overfitting and Underfitting**
# 13. **Regularization (L1, L2)**
# 14. **Learning Rate and Optimization**
# 15. **Cross-Entropy Loss**
# 16. **Softmax Function**
# 17. **Convolutional Neural Networks (CNN)**
# 18. **Recurrent Neural Networks (RNN)**
# 19. **Dropout**
# 20. **Batch Normalization**
# 21. **Hyperparameters and Model Tuning**
# 22. **Early Stopping**
# 23. **Transfer Learning**
# 24. **Activation Maps and Feature Maps**
# 25. **Loss Surface and Local Minima**
# 26. **Gradient Checking**
#
# Bu sıralama, temel kavramlardan daha ileri düzey kavramlara doğru bir öğrenme yolculuğunu takip edecek şekilde düzenlenmiştir.

# %% [markdown]
# ## **Perceptron**
#
# A **Perceptron** is a type of artificial neural network unit and one of the simplest forms of a neural network model. It was introduced by Frank Rosenblatt in the 1950s and serves as a basic building block for more complex neural networks.
#
# ### Key Components of a Perceptron
#
# 1. **Inputs**: The perceptron receives one or more input values, often denoted as $x_1, x_2, \dots, x_n$.
#
# 2. **Weights**: Each input has a corresponding weight ($w_1, w_2, \dots, w_n$) which indicates the importance of that input.
#
# 3. **Weighted Sum**: The perceptron calculates a weighted sum of the inputs:
#
#    $$
#    z = w_1 x_1 + w_2 x_2 + \dots + w_n x_n + b
#    $$
#
#    Here, $b$ is the **bias** term, which helps shift the decision boundary.
#
# 4. **Activation Function**: The weighted sum $z$ is passed through an activation function to produce the output. In a basic perceptron, this is usually a **step function**, which outputs a binary value (e.g., 0 or 1):
#
# $$
# \mathrm{output} =
# \begin{cases}
# 1 & \text{if } z \geq 0 \\
# 0 & \text{if } z < 0
# \end{cases}
# $$
#
# ### Functionality
# The perceptron can be seen as a linear classifier that separates data into two classes using a **decision boundary** (a line, plane, or hyperplane depending on the number of dimensions). During the training process, the perceptron adjusts its weights and bias to correctly classify input data.
#
# ### Limitations
# - The basic perceptron can only solve **linearly separable problems** (e.g., problems where a single line can separate classes).
# - It cannot handle more complex tasks that require non-linear decision boundaries (like the XOR problem).
#
# ### Usage and Evolution
# - A single-layer perceptron is limited to simple classification tasks.
# - A **Multi-Layer Perceptron (MLP)**, which includes multiple layers of perceptrons with non-linear activation functions, can solve more complex tasks and is the foundation of modern neural networks.
#
# ### Example
# For a simple two-input perceptron model:
# - **Inputs**: $x_1$ and $x_2$
# - **Weights**: $w_1$ and $w_2$
# - **Bias**: $b$
# - The output is:
#
# $$
# \mathrm{output} =
# \begin{cases}
# 1 & \text{if } w_1 x_1 + w_2 x_2 + b \geq 0 \\
# 0 & \text{if } w_1 x_1 + w_2 x_2 + b < 0
# \end{cases}
# $$
